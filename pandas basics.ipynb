# %%
import pandas as pd

# %%
import pandas as pd

data = {
   'Name': ['John', 'Alice', 'Bob'],
   'Age': [25, 30, 35],
   'City': ['New York', 'London', 'Paris']
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age      City
# 0   John   25  New York
# 1  Alice   30    London
# 2    Bob   35     Paris

# %%
mm
